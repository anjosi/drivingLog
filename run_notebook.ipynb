# %% [raw]
# Syötetiedostoissa ensimmäinen rivi on oltava tyhjä ja sen jälkeen heti ensimmäinen päivämäärä rivi, muuten homma leviää käsiin. Äläkä yritä kääntää txt-tiedostoja csv-tiedostoiksi excelissä. Syötä txt-tiedostot suoraan drivingLogApp-ohjelmalle.

# %%
from drivingLogApp import *
app=logApplication()
app.addLogFile()
app.addLogFile('ajot_2.txt')
app.addLogFile('ajot_3.txt')
app.addLogFile('ajot_4.txt')
# Out:
# ajot_1.txt
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# handling the aller.
# ...

# %%
app._makeExcel()
